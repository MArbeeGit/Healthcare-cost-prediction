# %%
# Import necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Set style for plots
sns.set(style="whitegrid")

# %%
# Step 1: Load the Dataset
data = pd.read_csv('../data/insurance.csv')

# Display the first few rows of the dataset
print("First 5 rows of the dataset:")
display(data.head())
# Out:
# First 5 rows of the dataset:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
# Step 2: Check Basic Information
print("\nDataset Information:")
print(data.info())

# Check for missing values
print("\nMissing Values:")
print(data.isnull().sum())
# Out:
# Dataset Information:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB
# None
#
# Missing Values:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
# Step 3: Descriptive Statistics
print("\nDescriptive Statistics:")
display(data.describe())
# Out:
# Descriptive Statistics:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %%
# Step 4: Visualize Distributions - Histogram for Charges
plt.figure(figsize=(10, 6))
sns.histplot(data['charges'], kde=True, bins=30)
plt.title('Distribution of Healthcare Costs')
plt.xlabel('Charges')
plt.ylabel('Frequency')
plt.show()

# %%
# Step 4: Visualize Distributions - Boxplot for Smoker vs Charges
plt.figure(figsize=(10, 6))
sns.boxplot(x='smoker', y='charges', data=data)
plt.title('Smoker vs Healthcare Costs')
plt.xlabel('Smoker')
plt.ylabel('Charges')
plt.show()

# %%
# Step 4: Visualize Distributions - Boxplot for Region vs Charges
plt.figure(figsize=(10, 6))
sns.boxplot(x='region', y='charges', data=data)
plt.title('Region vs Healthcare Costs')
plt.xlabel('Region')
plt.ylabel('Charges')
plt.show()

# %%
# Step 4: Visualize Distributions - Scatter Plot for Age vs Charges
plt.figure(figsize=(10, 6))
sns.scatterplot(x='age', y='charges', hue='smoker', data=data)
plt.title('Age vs Healthcare Costs (Colored by Smoker)')
plt.xlabel('Age')
plt.ylabel('Charges')
plt.show()

# %%
# Step 5: Correlation Analysis
# One-hot encode categorical variables for correlation matrix
data_encoded = pd.get_dummies(data, drop_first=True)

# Calculate correlation matrix
correlation_matrix = data_encoded.corr()

# Plot heatmap
plt.figure(figsize=(12, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Matrix')
plt.show()

# %%
# Step 6: Insights from EDA
print("\nKey Insights from EDA:")
print("- The distribution of healthcare costs is right-skewed, with a few high-cost outliers.")
print("- Smokers tend to have significantly higher healthcare costs compared to non-smokers.")
print("- Age shows a moderate positive correlation with healthcare costs.")
print("- BMI has a weaker but noticeable correlation with healthcare costs.")
print("- Region does not appear to have a strong impact on healthcare costs.")
# Out:
# Key Insights from EDA:
# - The distribution of healthcare costs is right-skewed, with a few high-cost outliers.
# - Smokers tend to have significantly higher healthcare costs compared to non-smokers.
# - Age shows a moderate positive correlation with healthcare costs.
# - BMI has a weaker but noticeable correlation with healthcare costs.
# - Region does not appear to have a strong impact on healthcare costs.
